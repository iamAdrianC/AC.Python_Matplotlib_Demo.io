# %% [markdown]
# ## Import matplotlib library

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Style use

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# # The basics of a pie chart

# %%
slices = [120,80,30, 20]
labels = ['Sixty', 'Forty', 'Extra1', 'Extra2']
colors = ['#008fd5', '#fc4f30', '#e5ae37', '#6d904f']
plt.pie(slices, labels=labels, colors=colors, wedgeprops={'edgecolor':'black'})

plt.title('My Awesome Pie Chart')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Real world example

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]

# %%
plt.pie(slices, labels=labels, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x1884b5777f0>,
#   <matplotlib.patches.Wedge at 0x1884b577cd0>,
#   <matplotlib.patches.Wedge at 0x1884b587190>,
#   <matplotlib.patches.Wedge at 0x1884b587610>,
#   <matplotlib.patches.Wedge at 0x1884b587a90>],
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.1325149391889142, -1.0919889151872186, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %% [markdown]
# ## Emphasis on Python (explode)

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]

# %%
plt.pie(slices, labels=labels, explode=explode, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x1884b5c8610>,
#   <matplotlib.patches.Wedge at 0x1884b5c8af0>,
#   <matplotlib.patches.Wedge at 0x1884b5c8f70>,
#   <matplotlib.patches.Wedge at 0x1884b5d63d0>,
#   <matplotlib.patches.Wedge at 0x1884b5d6850>],
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.14456175184245185, -1.191260634749693, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %% [markdown]
# ## Use of shadow to show depth

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x1884b6192e0>,
#   <matplotlib.patches.Wedge at 0x1884b6199a0>,
#   <matplotlib.patches.Wedge at 0x1884b6270a0>,
#   <matplotlib.patches.Wedge at 0x1884b627700>,
#   <matplotlib.patches.Wedge at 0x1884b627d60>],
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.14456175184245185, -1.191260634749693, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %% [markdown]
# ## Rotate chart at 90 degrees

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x1884b668df0>,
#   <matplotlib.patches.Wedge at 0x1884b6783a0>,
#   <matplotlib.patches.Wedge at 0x1884b678a30>,
#   <matplotlib.patches.Wedge at 0x1884b6870d0>,
#   <matplotlib.patches.Wedge at 0x1884b687790>],
#  [Text(-0.7837501906172629, 0.7718391274789094, 'JavaScript'),
#   Text(-0.7987513829484706, -0.7563043225037827, 'HTML/CSS'),
#   Text(0.5906400253912186, -0.9279786422142812, 'SQL'),
#   Text(1.191260634749693, 0.1445617518424518, 'Python'),
#   Text(0.508929586614865, 0.9751875080557701, 'Java')])

# %% [markdown]
# ## To show percentage to each slice

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor':'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x1884b6cb6d0>,
#   <matplotlib.patches.Wedge at 0x1884b6cbfd0>,
#   <matplotlib.patches.Wedge at 0x1884b6da940>,
#   <matplotlib.patches.Wedge at 0x1884b6e9250>,
#   <matplotlib.patches.Wedge at 0x1884b6e9b20>],
#  [Text(-0.7837501906172629, 0.7718391274789094, 'JavaScript'),
#   Text(-0.7987513829484706, -0.7563043225037827, 'HTML/CSS'),
#   Text(0.5906400253912186, -0.9279786422142812, 'SQL'),
#   Text(1.191260634749693, 0.1445617518424518, 'Python'),
#   Text(0.508929586614865, 0.9751875080557701, 'Java')],
#  [Text(-0.42750010397305244, 0.4210031604430415, '25.2%'),
#   Text(-0.4356825725173476, -0.4125296304566087, '23.6%'),
#   Text(0.3221672865770283, -0.5061701684805169, '20.3%'),
#   Text(0.6949020369373209, 0.08432768857476353, '15.5%'),
#   Text(0.27759795633538087, 0.5319204589395109, '15.3%')])

# %% [markdown]
# ## Final

# %%
plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=90, autopct='%1.1f%%', wedgeprops={'edgecolor':'black'})

plt.title('My Awesome Pie Chart')
plt.tight_layout()
plt.show()
